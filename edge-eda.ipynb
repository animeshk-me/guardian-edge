# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
count_dataset_A = 1000
count_dataset_B = 1000

df_full = pd.read_csv(r"C:\Users\24ani\Documents\ACM School\imu_data\falling_20260103_163148.csv")
df_full.head()
# df_A = pd.read_csv(r"C:\Users\24ani\Documents\ACM School\Data Collection\imu_data\animesh\jogging_20251228_183925.csv")
# df_B = pd.read_csv(r"C:\Users\24ani\Documents\ACM School\Data Collection\imu_data\animesh\jogging_20251228_183925.csv")
# Out:
#   Device  timestamp        ax        ay        az        gx        gy  \
# 0      A      27313  0.013306  0.652222 -0.770752 -0.183106 -0.671387
# 1      B     164216 -0.009277 -0.995728  0.086670 -0.061035 -0.427246
# 2      A      27333  0.013550  0.652954 -0.769775 -0.183106 -0.671387
# 3      A      27353  0.013428  0.651245 -0.770142 -0.061035 -0.671387
# 4      B     164236 -0.009766 -0.994751  0.086182 -0.061035 -0.427246
#
#          gz activity
# 0  0.427246  falling
# 1 -0.305176  falling
# 2  0.427246  falling
# 3  0.427246  falling
# 4 -0.366211  falling
